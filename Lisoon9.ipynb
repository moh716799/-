# %% [markdown]
# <a href="https://colab.research.google.com/github/moh716799/-/blob/main/Lisoon9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **إستدعاء المكتبات**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %% [markdown]
# # **تحميل البيانات وتقسيمها**

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # إستكشاف البيانات

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title(f'Label: {y_train[0]}')
plt.show()

# %% [markdown]
# # تهيئة البيانات

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # بناء النموذج (شبكة عصبيه بسيطه )

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # تجميع النموذج

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # تدريب النموذج

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8551 - loss: 0.4910
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9559 - loss: 0.1512
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9674 - loss: 0.1104
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9734 - loss: 0.0891
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9770 - loss: 0.0760

# %% [markdown]
# # تقييم النموذج

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9717 - loss: 0.0896
# Test Accuracy: 0.9764000177383423

# %%
# !pip freeze > requirements.txt

# %%
# !cat requirements.txt
# Out:
# absl-py==1.4.0
# accelerate==1.9.0
# aiofiles==24.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.12.15
# aiosignal==1.4.0
# alabaster==1.0.0
# albucore==0.0.24
# albumentations==2.0.8
# ale-py==0.11.2
# altair==5.5.0
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.9.0
# anywidget==0.9.18
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# array_record==0.7.2
# arviz==0.22.0
# astropy==7.1.0
# astropy-iers-data==0.2025.7.28.0.41.50
# astunparse==1.6.3
# atpublic==5.1
# attrs==25.3.0
# audioread==3.0.1
# autograd==1.8.0
# babel==2.17.0
# backcall==0.2.0
# backports.tarfile==1.2.0
# beautifulsoup4==4.13.4
# betterproto==2.0.0b6
# bigframes==2.13.0
# bigquery-magics==0.10.1
# bleach==6.2.0
# blinker==1.9.0
# blis==1.3.0
# blobfile==3.0.0
# blosc2==3.6.1
# bokeh==3.7.3
# Bottleneck==1.4.2
# bqplot==0.12.45
# branca==0.8.1
# Brotli==1.1.0
# build==1.3.0
# CacheControl==0.14.3
# cachetools==5.5.2
# catalogue==2.0.10
# certifi==2025.7.14
# cffi==1.17.1
# chardet==5.2.0
# ...
